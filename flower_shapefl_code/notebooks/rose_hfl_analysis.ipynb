# %% [markdown]
# # RoSE-HFL Analysis Notebook
#
# This notebook is the contract notebook for loading RoSE result directories and regenerating thesis figures/tables.

# %%
from pathlib import Path
import json

RUN_ROOT = Path('results')
print(RUN_ROOT.resolve())

# %%
# Load metrics.json, fairness.json, privacy.json, and shapley_history.json from RoSE run directories here.
