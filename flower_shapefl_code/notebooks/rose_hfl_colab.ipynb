# %% [markdown]
# # RoSE-HFL Colab Runner
#
# This notebook is the contract notebook for long-form RoSE-HFL experiment execution on Colab.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Example contract cell: clone, install, then invoke scripts.run_rose_simulation with --resume.
# Fill in repository URL and desired run grid before execution.
